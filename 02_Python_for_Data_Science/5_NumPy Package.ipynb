# %% [markdown]
# # 5.1 Arrays

# %%
# Load NumPy package
import numpy as np

# %%
# Create two-dimensional array
myArray = np.array([[10, 20, 30], [210, 220, 230]])

# %%
# Display the array
myArray
# Out:
# array([[ 10,  20,  30],
#        [210, 220, 230]])

# %%
# Display the shape
myArray.shape
# Out:
# (2, 3)

# %%
# Display the size
myArray.size
# Out:
# 6

# %%
# Access the second row and third column
myArray[1, 2]
# Out:
# np.int64(230)

# %%
# Access the first row
myArray[0, :]
# Out:
# array([10, 20, 30])

# %%
# Access the first row's size
myArray[0, :].size
# Out:
# 3

# %%
myArray3 = np.array([[[10, 20, 30], [210, 220, 230]] , [[11, 22, 33], [211, 222, 233]]])
myArray3
# Out:
# array([[[ 10,  20,  30],
#         [210, 220, 230]],
#
#        [[ 11,  22,  33],
#         [211, 222, 233]]])

# %% [markdown]
# ## 5.2 Array functions

# %%
# Create array
array1 = np.array([['a', 'a'], ['b', 'b'], ['c', 'c']])
array1
# Out:
# array([['a', 'a'],
#        ['b', 'b'],
#        ['c', 'c']], dtype='<U1')

# %%
# Insert 'z's in row 3
np.insert(array1, 3, 'z', axis=0)
# Out:
# array([['a', 'a'],
#        ['b', 'b'],
#        ['c', 'c'],
#        ['z', 'z']], dtype='<U1')

# %% [markdown]
# ## 5.3: Shape functions

# %%
# Create an array
array1 = np.array([[1, 2], [3, 4]])
array1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
# Return a flattened array
np.reshape(array1, (1, 4))
# Out:
# array([[1, 2, 3, 4]])

# %%
# Create another array
array2 = np.array([[1, 2], [3, 4], [5, 6]])
array2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
# Return a flattened array (default order='C')
np.ravel(array2)
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
# Return a flattened array
np.ravel(array2, order='F')
# Out:
# array([1, 3, 5, 2, 4, 6])

# %%
# Resize array to a 2 by 3 array
np.resize(array2, (2, 7))
# Out:
# array([[1, 2, 3, 4, 5, 6, 1],
#        [2, 3, 4, 5, 6, 1, 2]])

# %%
# Transpose the array
np.transpose(array2)
# Out:
# array([[1, 3, 5],
#        [2, 4, 6]])

# %% [markdown]
# ## 5.4: Math operators and functions

# %%
# Create array1
array1 = np.array([[1, 2], [3, 4]])
array1
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
array1 + 2
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
# Create array2
array2 = np.array([[5, 6], [7, 8]])
array2
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
# Add array1 and array2
array1 + array2
# Out:
# array([[ 6,  8],
#        [10, 12]])

# %%
# Subtract array1 and array2
array1 - array2
# Out:
# array([[-4, -4],
#        [-4, -4]])

# %%
# Multiply array1 and array2
array1 * array2
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
# Divide array1 by array2
array1 / array2
# Out:
# array([[0.2       , 0.33333333],
#        [0.42857143, 0.5       ]])

# %%
# Find square root of array 2 elements
np.sqrt(array2)
# Out:
# array([[2.23606798, 2.44948974],
#        [2.64575131, 2.82842712]])

# %%
# Find the dot product of rows of array1 and columns of array2
np.dot(array1, array2)
# Out:
# array([[19, 22],
#        [43, 50]])

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np
arr = np.array([1, 10, 5, 20])
#mask = arr > 5  # Returns [False,  True, False,  True]
#filtered = arr[mask] # Returns [10, 20]
arr[arr>5]
# Out:
# array([10, 20])
